# %%
import ir_datasets
import pandas as pd

# %%
docs = pd.read_csv('data/docs.csv')

queries = pd.read_csv('data/queries.csv')

# %%
docs
# Out:
#            id                                              title  \
# 0      MED-14  Statin use after diagnosis of breast cancer an...
# 1     MED-118  Alkylphenols in human milk and their relations...
# 2     MED-301  Methylmercury: A Potential Environmental Risk ...
# 3     MED-306  Sensitivity of Continuous Performance Test (CP...
# 4     MED-329                     Phosphate is a vascular toxin.
# ...       ...                                                ...
# 3627  MED-917  Effect of freezing and storage on the phenolic...
# 3628  MED-941  Topical vitamin A treatment of recalcitrant co...
# 3629  MED-942  Esophageal injury by apple cider vinegar table...
# 3630  MED-952                             Cannabis and the lung.
# 3631  MED-961  Vitamin D(3) is more potent than vitamin D(2) ...
#
#                                                    text  \
# 0     BACKGROUND: Preclinical studies have shown tha...
# 1     The aims of this study were to determine the c...
# ...

# %%
queries
# Out:
#               id                                               text  \
# 0        PLAIN-3            Breast Cancer Cells Feed on Cholesterol
# 1        PLAIN-4              Using Diet to Treat Asthma and Eczema
# 2        PLAIN-5              Treating Asthma With Plants vs. Pills
# 3        PLAIN-6         How Fruits and Vegetables Can Treat Asthma
# 4        PLAIN-7       How Fruits and Vegetables Can Prevent Asthma
# ...          ...                                                ...
# 3232  PLAIN-3432                       Healthy Chocolate Milkshakes
# 3233  PLAIN-3442                          The Healthiest Vegetables
# 3234  PLAIN-3452                           Bowel Movement Frequency
# 3235  PLAIN-3462                      Olive Oil and Artery Function
# 3236  PLAIN-3472  How Doctors Responded to Being Named a Leading...
#
#                                                     url
# 0     http://nutritionfacts.org/2015/07/14/breast-ca...
# ...
