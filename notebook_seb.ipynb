# %%
# %load_ext autoreload
# %autoreload 2


from utils import show_year_data
import pandas as pd

# %%
docs = pd.read_csv('data/docs.csv')
docs
# Out:
#             id                                              title  \
# 0       MED-14  Statin use after diagnosis of breast cancer an...
# 1      MED-118  Alkylphenols in human milk and their relations...
# 2      MED-301  Methylmercury: A Potential Environmental Risk ...
# 3      MED-306  Sensitivity of Continuous Performance Test (CP...
# 4      MED-329                     Phosphate is a vascular toxin.
# ...        ...                                                ...
# 3549  MED-4885  Flaxseed Supplementation (not Dietary Fat Rest...
# 3550  MED-4983  Meat intake and mortality: a prospective study...
# 3551  MED-5031  Sleep Habits and Susceptibility to the Common ...
# 3552  MED-5060  Domestic and farm-animal exposures and risk of...
# 3553  MED-5066  Influence of a Diet Very High in Vegetables, F...
#
#                                                    text  \
# 0     BACKGROUND: Preclinical studies have shown tha...
# 1     The aims of this study were to determine the c...
# ...

# %%
show_year_data(docs)
